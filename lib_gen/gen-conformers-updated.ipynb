# %%
import generate_conformers as gc
import os
import molli as ml
import molli.external._rdkit as _rdkit

# %%
out_dir = './out_conformers1/'
in_dir = './in_combinatorial/combinatorial_lib.mlib'

# %%
gc.conformer_generation(in_dir, file_output=out_dir)
# Out:
# /home/ethangm2/NCSA Development/molli/molli/parsing/mol2.py:248: UserWarning: TRIPOS block 'UNITY' is not implemented in current version of MOLLI!. Lines will be skipped.
#   warn(
# /home/ethangm2/NCSA Development/molli/molli/parsing/mol2.py:248: UserWarning: TRIPOS block 'UNITY' is not implemented in current version of MOLLI!. Lines will be skipped.
#   warn(
# /home/ethangm2/NCSA Development/molli/molli/parsing/mol2.py:248: UserWarning: TRIPOS block 'UNITY' is not implemented in current version of MOLLI!. Lines will be skipped.
#   warn(
# /home/ethangm2/NCSA Development/molli/molli/parsing/mol2.py:248: UserWarning: TRIPOS block 'UNITY' is not implemented in current version of MOLLI!. Lines will be skipped.
#   warn(
# /home/ethangm2/NCSA Development/molli/molli/parsing/mol2.py:248: UserWarning: TRIPOS block 'UNITY' is not implemented in current version of MOLLI!. Lines will be skipped.
#   warn(
# ...

# %%
clib = ml.ConformerLibrary('./out_conformers1/conformers.mlib')
len(clib)
# Out:
# 75

# %%
cf = 0
for i in clib:
    print(i)
    cf += i.n_conformers
print(str(cf) + ' total conformers in library')
# Out:
# ConformerEnsemble(name='1_3', formula='C16 H26 Br2 N2 O2', n_conformers=150)
# ConformerEnsemble(name='1_2', formula='C14 H22 Br2 N2 O2', n_conformers=50)
# ConformerEnsemble(name='1_1', formula='C18 H30 Br2 N2 O2', n_conformers=50)
# ConformerEnsemble(name='1_4', formula='C12 H18 Br2 N2 O2', n_conformers=50)
# ConformerEnsemble(name='1_5', formula='C22 H34 Br2 N2 O2', n_conformers=28)
# ConformerEnsemble(name='1_11', formula='C22 H22 Br2 N2 O2', n_conformers=50)
# ConformerEnsemble(name='1_12', formula='C26 H30 Br2 N2 O2', n_conformers=150)
# ConformerEnsemble(name='1_14', formula='C30 H38 Br2 N2 O2', n_conformers=50)
# ConformerEnsemble(name='1_13', formula='C26 H18 Br2 F12 N2 O2', n_conformers=50)
# ConformerEnsemble(name='1_15', formula='C24 H26 Br2 N2 O2', n_conformers=50)
# ConformerEnsemble(name='1_8', formula='C28 H22 Br2 F12 N2 O2', n_conformers=50)
# ConformerEnsemble(name='1_7', formula='C28 H34 Br2 N2 O2', n_conformers=148)
# ...

# %% [markdown]
# Test altering parameters now, particularly threshold as bool vs int. Also test edge cases, like passing 0.

# %%
# Path passed instead of string, parameter values changed, file output changed
from pathlib import Path
in_path = Path(in_dir)
new_out = out_dir + 'conformers2.mlib'
gc.conformer_generation(in_path, n_confs = 25, maxIterations=1000, threshold=30, file_output=new_out)
# Out:
# /home/ethangm2/NCSA Development/molli/molli/parsing/mol2.py:248: UserWarning: TRIPOS block 'UNITY' is not implemented in current version of MOLLI!. Lines will be skipped.
#   warn(
# /home/ethangm2/NCSA Development/molli/molli/parsing/mol2.py:248: UserWarning: TRIPOS block 'UNITY' is not implemented in current version of MOLLI!. Lines will be skipped.
#   warn(
# /home/ethangm2/NCSA Development/molli/molli/parsing/mol2.py:248: UserWarning: TRIPOS block 'UNITY' is not implemented in current version of MOLLI!. Lines will be skipped.
#   warn(
# /home/ethangm2/NCSA Development/molli/molli/parsing/mol2.py:248: UserWarning: TRIPOS block 'UNITY' is not implemented in current version of MOLLI!. Lines will be skipped.
#   warn(
# /home/ethangm2/NCSA Development/molli/molli/parsing/mol2.py:248: UserWarning: TRIPOS block 'UNITY' is not implemented in current version of MOLLI!. Lines will be skipped.
#   warn(
# ...

# %%
clib = ml.ConformerLibrary('./out_conformers1/conformers2.mlib')
len(clib)
# Out:
# 75

# %%
cf = 0
for i in clib:
    print(i)
    cf += i.n_conformers
print(str(cf) + ' total conformers in library')
# Out:
# ConformerEnsemble(name='1_3', formula='C16 H26 Br2 N2 O2', n_conformers=75)
# ConformerEnsemble(name='1_2', formula='C14 H22 Br2 N2 O2', n_conformers=25)
# ConformerEnsemble(name='1_1', formula='C18 H30 Br2 N2 O2', n_conformers=25)
# ConformerEnsemble(name='1_4', formula='C12 H18 Br2 N2 O2', n_conformers=25)
# ConformerEnsemble(name='1_5', formula='C22 H34 Br2 N2 O2', n_conformers=25)
# ConformerEnsemble(name='1_11', formula='C22 H22 Br2 N2 O2', n_conformers=25)
# ConformerEnsemble(name='1_12', formula='C26 H30 Br2 N2 O2', n_conformers=75)
# ConformerEnsemble(name='1_14', formula='C30 H38 Br2 N2 O2', n_conformers=25)
# ConformerEnsemble(name='1_13', formula='C26 H18 Br2 F12 N2 O2', n_conformers=25)
# ConformerEnsemble(name='1_15', formula='C24 H26 Br2 N2 O2', n_conformers=25)
# ConformerEnsemble(name='1_8', formula='C28 H22 Br2 F12 N2 O2', n_conformers=25)
# ConformerEnsemble(name='1_7', formula='C28 H34 Br2 N2 O2', n_conformers=75)
# ...

# %%
# now raising parameters, setting threshold to true
out_path = Path(out_dir + 'conformers3.mlib')
gc.conformer_generation(in_path, n_confs = 60, maxIterations=11000, threshold=True, file_output=out_path)
# Out:
# /home/ethangm2/NCSA Development/molli/molli/parsing/mol2.py:248: UserWarning: TRIPOS block 'UNITY' is not implemented in current version of MOLLI!. Lines will be skipped.
#   warn(
# /home/ethangm2/NCSA Development/molli/molli/parsing/mol2.py:248: UserWarning: TRIPOS block 'UNITY' is not implemented in current version of MOLLI!. Lines will be skipped.
#   warn(
# /home/ethangm2/NCSA Development/molli/molli/parsing/mol2.py:248: UserWarning: TRIPOS block 'UNITY' is not implemented in current version of MOLLI!. Lines will be skipped.
#   warn(
# /home/ethangm2/NCSA Development/molli/molli/parsing/mol2.py:248: UserWarning: TRIPOS block 'UNITY' is not implemented in current version of MOLLI!. Lines will be skipped.
#   warn(
# /home/ethangm2/NCSA Development/molli/molli/parsing/mol2.py:248: UserWarning: TRIPOS block 'UNITY' is not implemented in current version of MOLLI!. Lines will be skipped.
#   warn(
# ...

# %%
clib = ml.ConformerLibrary('./out_conformers1/conformers3.mlib')
cf = 0
for i in clib:
    print(i)
    cf += i.n_conformers
print(str(cf) + ' total conformers in library')
# Out:
# ConformerEnsemble(name='1_3', formula='C16 H26 Br2 N2 O2', n_conformers=180)
# ConformerEnsemble(name='1_2', formula='C14 H22 Br2 N2 O2', n_conformers=60)
# ConformerEnsemble(name='1_1', formula='C18 H30 Br2 N2 O2', n_conformers=60)
# ConformerEnsemble(name='1_4', formula='C12 H18 Br2 N2 O2', n_conformers=60)
# ConformerEnsemble(name='1_5', formula='C22 H34 Br2 N2 O2', n_conformers=18)
# ConformerEnsemble(name='1_11', formula='C22 H22 Br2 N2 O2', n_conformers=60)
# ConformerEnsemble(name='1_12', formula='C26 H30 Br2 N2 O2', n_conformers=180)
# ConformerEnsemble(name='1_14', formula='C30 H38 Br2 N2 O2', n_conformers=60)
# ConformerEnsemble(name='1_13', formula='C26 H18 Br2 F12 N2 O2', n_conformers=60)
# ConformerEnsemble(name='1_15', formula='C24 H26 Br2 N2 O2', n_conformers=60)
# ConformerEnsemble(name='1_8', formula='C28 H22 Br2 F12 N2 O2', n_conformers=60)
# ConformerEnsemble(name='1_7', formula='C28 H34 Br2 N2 O2', n_conformers=178)
# ...

# %% [markdown]
# file in and out puts work as both strings or paths. Now to test edge cases. Setting any numerical parmeters to 0. threshold to false.

# %%
# threshold = false, num processes halved
out_path = Path(out_dir + 'conformers3.mlib')
gc.conformer_generation(in_path, num_processes=50, threshold=False, file_output=out_path)
# Out:
# /home/ethangm2/NCSA Development/molli/molli/storage/library.py:95: UserWarning: Requested path was not available. New file name: out_conformers1/conformers3___001.mlib
#   warn(f"Requested path was not available. New file name: {_path}")
# /home/ethangm2/NCSA Development/molli/molli/parsing/mol2.py:248: UserWarning: TRIPOS block 'UNITY' is not implemented in current version of MOLLI!. Lines will be skipped.
#   warn(
# /home/ethangm2/NCSA Development/molli/molli/parsing/mol2.py:248: UserWarning: TRIPOS block 'UNITY' is not implemented in current version of MOLLI!. Lines will be skipped.
#   warn(
# /home/ethangm2/NCSA Development/molli/molli/parsing/mol2.py:248: UserWarning: TRIPOS block 'UNITY' is not implemented in current version of MOLLI!. Lines will be skipped.
#   warn(
# /home/ethangm2/NCSA Development/molli/molli/parsing/mol2.py:248: UserWarning: TRIPOS block 'UNITY' is not implemented in current version of MOLLI!. Lines will be skipped.
#   warn(
# ...

# %%
clib = ml.ConformerLibrary('./out_conformers1/conformers3___001.mlib')
cf = 0
for i in clib:
    print(i)
    cf += i.n_conformers
print(str(cf) + ' total conformers in library')
# Out:
# ConformerEnsemble(name='1_3', formula='C16 H26 Br2 N2 O2', n_conformers=150)
# ConformerEnsemble(name='1_2', formula='C14 H22 Br2 N2 O2', n_conformers=50)
# ConformerEnsemble(name='1_1', formula='C18 H30 Br2 N2 O2', n_conformers=50)
# ConformerEnsemble(name='1_4', formula='C12 H18 Br2 N2 O2', n_conformers=50)
# ConformerEnsemble(name='1_5', formula='C22 H34 Br2 N2 O2', n_conformers=50)
# ConformerEnsemble(name='1_11', formula='C22 H22 Br2 N2 O2', n_conformers=50)
# ConformerEnsemble(name='1_12', formula='C26 H30 Br2 N2 O2', n_conformers=150)
# ConformerEnsemble(name='1_14', formula='C30 H38 Br2 N2 O2', n_conformers=50)
# ConformerEnsemble(name='1_13', formula='C26 H18 Br2 F12 N2 O2', n_conformers=50)
# ConformerEnsemble(name='1_15', formula='C24 H26 Br2 N2 O2', n_conformers=50)
# ConformerEnsemble(name='1_8', formula='C28 H22 Br2 F12 N2 O2', n_conformers=50)
# ConformerEnsemble(name='1_7', formula='C28 H34 Br2 N2 O2', n_conformers=150)
# ...

# %% [markdown]
# Time to set things to 0

# %%
#break n_confs
out_path = Path(out_dir + 'conformers00.mlib')
gc.conformer_generation(in_path, n_confs=0, file_output=out_path)
# Out:
# Failure for <rdkit.Chem.rdchem.Mol object at 0x7f7a2f78ac70> on conformer geometry optimization: Bad Conformer IdFailure for <rdkit.Chem.rdchem.Mol object at 0x7f7a2f78ac70> on conformer geometry optimization: Bad Conformer Id
#
# Failure for <rdkit.Chem.rdchem.Mol object at 0x7f7a2f78ac70> on conformer geometry optimization: Bad Conformer Id
# Failure for <rdkit.Chem.rdchem.Mol object at 0x7f7a2f78ac70> on conformer geometry optimization: Bad Conformer Id
# Failure for <rdkit.Chem.rdchem.Mol object at 0x7f7a2f78ac70> on conformer geometry optimization: Bad Conformer IdFailure for <rdkit.Chem.rdchem.Mol object at 0x7f7a2f78ac70> on conformer geometry optimization: Bad Conformer IdFailure for <rdkit.Chem.rdchem.Mol object at 0x7f7a2f78ac70> on conformer geometry optimization: Bad Conformer Id
#
# Failure for <rdkit.Chem.rdchem.Mol object at 0x7f7a2f78ac70> on conformer geometry optimization: Bad Conformer Id
#
# ...

# %%
clib = ml.ConformerLibrary('./out_conformers1/conformers00.mlib')
print(len(clib))
# Out:
# 0

# %%
#break maxIterations
out_path = Path(out_dir + 'conformers01.mlib')
gc.conformer_generation(in_path, maxIterations=0, file_output=out_path)
# Out:
# /home/ethangm2/NCSA Development/molli/molli/parsing/mol2.py:248: UserWarning: TRIPOS block 'UNITY' is not implemented in current version of MOLLI!. Lines will be skipped.
#   warn(
# /home/ethangm2/NCSA Development/molli/molli/parsing/mol2.py:248: UserWarning: TRIPOS block 'UNITY' is not implemented in current version of MOLLI!. Lines will be skipped.
#   warn(
# /home/ethangm2/NCSA Development/molli/molli/parsing/mol2.py:248: UserWarning: TRIPOS block 'UNITY' is not implemented in current version of MOLLI!. Lines will be skipped.
#   warn(
# /home/ethangm2/NCSA Development/molli/molli/parsing/mol2.py:248: UserWarning: TRIPOS block 'UNITY' is not implemented in current version of MOLLI!. Lines will be skipped.
#   warn(
# /home/ethangm2/NCSA Development/molli/molli/parsing/mol2.py:248: UserWarning: TRIPOS block 'UNITY' is not implemented in current version of MOLLI!. Lines will be skipped.
#   warn(
# ...

# %%
clib = ml.ConformerLibrary('./out_conformers1/conformers01.mlib')
cf = 0
for i in clib:
    print(i)
    cf += i.n_conformers
print(str(cf) + ' total conformers in library')
# Out:
# ConformerEnsemble(name='1_3', formula='C16 H26 Br2 N2 O2', n_conformers=150)
# ConformerEnsemble(name='1_2', formula='C14 H22 Br2 N2 O2', n_conformers=50)
# ConformerEnsemble(name='1_1', formula='C18 H30 Br2 N2 O2', n_conformers=50)
# ConformerEnsemble(name='1_4', formula='C12 H18 Br2 N2 O2', n_conformers=50)
# ConformerEnsemble(name='1_5', formula='C22 H34 Br2 N2 O2', n_conformers=28)
# ConformerEnsemble(name='1_11', formula='C22 H22 Br2 N2 O2', n_conformers=50)
# ConformerEnsemble(name='1_12', formula='C26 H30 Br2 N2 O2', n_conformers=150)
# ConformerEnsemble(name='1_14', formula='C30 H38 Br2 N2 O2', n_conformers=50)
# ConformerEnsemble(name='1_13', formula='C26 H18 Br2 F12 N2 O2', n_conformers=50)
# ConformerEnsemble(name='1_15', formula='C24 H26 Br2 N2 O2', n_conformers=50)
# ConformerEnsemble(name='1_8', formula='C28 H22 Br2 F12 N2 O2', n_conformers=50)
# ConformerEnsemble(name='1_7', formula='C28 H34 Br2 N2 O2', n_conformers=148)
# ...

# %% [markdown]
# maxIterations = 0 is valid?

# %%
#break processes
out_path = Path(out_dir + 'conformers01.mlib')
gc.conformer_generation(in_path, num_processes=0, file_output=out_path)
# Out:
# /home/ethangm2/NCSA Development/molli/molli/storage/library.py:95: UserWarning: Requested path was not available. New file name: out_conformers1/conformers01___001.mlib
#   warn(f"Requested path was not available. New file name: {_path}")
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 3
#       1 #break processes
#       2 out_path = Path(out_dir + 'conformers01.mlib')
# ----> 3 gc.conformer_generation(in_path, num_processes=0, file_output=out_path)
#
# File ~/NCSA Development/molli/lib_gen/generate_conformers.py:283, in conformer_generation(mlib, n_confs, maxIterations, threshold, file_output, num_processes)
#     280     return
#     282 ensembles = None    # generate conformer ensembles, append to conformer library
# --> 283 with Pool(num_processes) as p:
#     284     ensembles = p.map(_conf_gen, args)
#     285 with clib:
#
# ...

# %% [markdown]
# Catch exceptions for n_confs/processes < 0

# %%
from pathlib import Path
in_path = Path(in_dir)

# %%
#break n_confs
out_path = Path(out_dir + 'conformers02.mlib')
gc.conformer_generation(in_path, n_confs=0, file_output=out_path)
# Out:
# Invalid n_confs value: must be greater than 0

# %%
#break num_processes
out_path = Path(out_dir + 'conformers02.mlib')
gc.conformer_generation(in_path, num_processes=0, file_output=out_path)
# Out:
# Invalid n_processes value: must be greater than 0
